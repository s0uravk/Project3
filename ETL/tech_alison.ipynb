# %%
# Import the dependencies.

# Import the dependencies.

import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from flask import Flask, json, jsonify, render_template

# %%
username = 'stock_analysis_user'
password = 'b2Qc7nHf8bW60JjeftiuI2gkZWmGFjxT'
host_address = 'dpg-cncljaev3ddc73c7nbjg-a.oregon-postgres.render.com'
cxn_string = f'postgresql+psycopg2://{username}:{password}@{host_address}/stock_analysis'
cxn_string
# Out:
# 'postgresql+psycopg2://stock_analysis_user:b2Qc7nHf8bW60JjeftiuI2gkZWmGFjxT@dpg-cncljaev3ddc73c7nbjg-a.oregon-postgres.render.com/stock_analysis'

# %%
cxn_string = f'postgresql+psycopg2://{username}:{password}@{host_address}/stock_analysis'
print(cxn_string)
# Create the SQLAlchemy engine
engine = create_engine(cxn_string, echo = False)#, execution_options={"frozen_modules": False})

Base = automap_base()

# Reflect all tables from the database schema
Base.prepare(autoload_with = engine)
# Out:
# postgresql+psycopg2://stock_analysis_user:b2Qc7nHf8bW60JjeftiuI2gkZWmGFjxT@dpg-cncljaev3ddc73c7nbjg-a.oregon-postgres.render.com/stock_analysis

# %%
print (Base.classes.keys())
total_volume = Base.classes["Total_Volume"]
# Out:
# ['Summary', 'Total_Volume', 'Final_Data']

# %%
session = Session(bind = engine)
vol_data = [
    total_volume.year, 
    total_volume.ticker,
    total_volume.total_volume
]

# %%
data = session.query(*vol_data)
vol_list = []
for d in data:
    data = {
        'Year' : d.year,
        'Ticker': d.ticker,
        'Total_Volume': d.total_volume
    }
    vol_list.append(data)

session.close()

# %%
vol_list
# Out:
# [{'Year': 2023, 'Ticker': 'TSLA', 'Total_Volume': 34339225708.0},
#  {'Year': 2022, 'Ticker': 'AMD', 'Total_Volume': 22939283690.0},
#  {'Year': 2021, 'Ticker': 'AAPL', 'Total_Volume': 22798348120.0},
#  {'Year': 2022, 'Ticker': 'AAPL', 'Total_Volume': 22050192133.0},
#  {'Year': 2018, 'Ticker': 'AMD', 'Total_Volume': 21154399914.0},
#  {'Year': 2021, 'Ticker': 'F', 'Total_Volume': 19834224649.0},
#  {'Year': 2020, 'Ticker': 'F', 'Total_Volume': 19386854291.0},
#  {'Year': 2020, 'Ticker': 'AAPL', 'Total_Volume': 18552582945.0},
#  {'Year': 2022, 'Ticker': 'F', 'Total_Volume': 18223374932.0},
#  {'Year': 2019, 'Ticker': 'AMD', 'Total_Volume': 16736086831.0},
#  {'Year': 2020, 'Ticker': 'AMD', 'Total_Volume': 15581845598.0},
#  {'Year': 2023, 'Ticker': 'AMD', 'Total_Volume': 15401551836.0},
#  {'Year': 2023, 'Ticker': 'F', 'Total_Volume': 14511128198.0},
#  {'Year': 2023, 'Ticker': 'AAPL', 'Total_Volume': 13831665750.0},
#  {'Year': 2022, 'Ticker': 'NVDA', 'Total_Volume': 13629799053.0},
#  {'Year': 2021, 'Ticker': 'AMD', 'Total_Volume': 12910494192.0},
#  {'Year': 2022, 'Ticker': 'TSLA', 'Total_Volume': 12681148561.0},
#  {'Year': 2023, 'Ticker': 'NVDA', 'Total_Volume': 11837827887.0},
#  {'Year': 2018, 'Ticker': 'F', 'Total_Volume': 11045923658.0},
#  {'Year': 2018, 'Ticker': 'MU', 'Total_Volume': 10854447338.0},
#  {'Year': 2023, 'Ticker': 'INTC', 'Total_Volume': 10458122333.0},
#  {'Year': 2022, 'Ticker': 'INTC', 'Total_Volume': 9797815225.0},
#  {'Year': 2019, 'Ticker': 'F', 'Total_Volume': 9664074692.0},
#  {'Year': 2020, 'Ticker': 'MSFT', 'Total_Volume': 9525255449.0},
#  {'Year': 2018, 'Ticker': 'AAPL', 'Total_Volume': 8467093298.0},
#  {'Year': 2021, 'Ticker': 'PFE', 'Total_Volume': 8285808834.0},
#  {'Year': 2020, 'Ticker': 'PFE', 'Total_Volume': 8211387361.0},
#  {'Year': 2020, 'Ticker': 'INTC', 'Total_Volume': 7987809814.0},
#  {'Year': 2018, 'Ticker': 'MSFT', 'Total_Volume': 7845245542.0},
#  {'Year': 2022, 'Ticker': 'MSFT', 'Total_Volume': 7828874003.0},
#  {'Year': 2020, 'Ticker': 'TSLA', 'Total_Volume': 7541015999.0},
#  {'Year': 2018, 'Ticker': 'INTC', 'Total_Volume': 7296698358.0},
#  {'Year': 2021, 'Ticker': 'INTC', 'Total_Volume': 7240841218.0},
#  {'Year': 2019, 'Ticker': 'AAPL', 'Total_Volume': 7086568153.0},
#  {'Year': 2023, 'Ticker': 'PFE', 'Total_Volume': 7054855020.0},
#  {'Year': 2021, 'Ticker': 'TSLA', 'Total_Volume': 6895260777.0},
#  {'Year': 2019, 'Ticker': 'MU', 'Total_Volume': 6686586480.0},
#  {'Year': 2021, 'Ticker': 'MSFT', 'Total_Volume': 6549434731.0},
#  {'Year': 2023, 'Ticker': 'MSFT', 'Total_Volume': 6462647004.0},
#  {'Year': 2019, 'Ticker': 'MSFT', 'Total_Volume': 6215102095.0},
#  {'Year': 2022, 'Ticker': 'PFE', 'Total_Volume': 6074912566.0},
#  {'Year': 2019, 'Ticker': 'PFE', 'Total_Volume': 5744360831.0},
#  {'Year': 2020, 'Ticker': 'MU', 'Total_Volume': 5740641853.0},
#  {'Year': 2018, 'Ticker': 'PFE', 'Total_Volume': 5653420257.0},
#  {'Year': 2019, 'Ticker': 'INTC', 'Total_Volume': 5537871012.0},
#  {'Year': 2021, 'Ticker': 'NVDA', 'Total_Volume': 5307430091.0},
#  {'Year': 2021, 'Ticker': 'MU', 'Total_Volume': 4946456654.0},
#  {'Year': 2022, 'Ticker': 'MU', 'Total_Volume': 4846322752.0},
#  {'Year': 2021, 'Ticker': 'GM', 'Total_Volume': 4821332712.0},
#  {'Year': 2020, 'Ticker': 'MRNA', 'Total_Volume': 4661963843.0},
#  {'Year': 2022, 'Ticker': 'GM', 'Total_Volume': 4136830700.0},
#  {'Year': 2024, 'Ticker': 'TSLA', 'Total_Volume': 3947608487.0},
#  {'Year': 2020, 'Ticker': 'GM', 'Total_Volume': 3903243795.0},
#  {'Year': 2023, 'Ticker': 'GM', 'Total_Volume': 3885973224.0},
#  {'Year': 2023, 'Ticker': 'MU', 'Total_Volume': 3516508112.0},
#  {'Year': 2020, 'Ticker': 'MS', 'Total_Volume': 3442832100.0},
#  {'Year': 2018, 'Ticker': 'NVDA', 'Total_Volume': 3411410693.0},
#  {'Year': 2019, 'Ticker': 'QCOM', 'Total_Volume': 3395687816.0},
#  {'Year': 2021, 'Ticker': 'MRNA', 'Total_Volume': 3346555880.0},
#  {'Year': 2022, 'Ticker': 'TSM', 'Total_Volume': 3240068956.0},
#  {'Year': 2018, 'Ticker': 'QCOM', 'Total_Volume': 3223307394.0},
#  {'Year': 2021, 'Ticker': 'MRK', 'Total_Volume': 3190790673.0},
#  {'Year': 2018, 'Ticker': 'GM', 'Total_Volume': 3132602135.0},
#  {'Year': 2020, 'Ticker': 'NVDA', 'Total_Volume': 3040265878.0},
#  {'Year': 2024, 'Ticker': 'AMD', 'Total_Volume': 2996029015.0},
#  {'Year': 2019, 'Ticker': 'INFY', 'Total_Volume': 2912238509.0},
#  {'Year': 2019, 'Ticker': 'NVDA', 'Total_Volume': 2883083510.0},
#  {'Year': 2020, 'Ticker': 'INFY', 'Total_Volume': 2882320326.0},
#  {'Year': 2018, 'Ticker': 'MRK', 'Total_Volume': 2824513804.0},
#  {'Year': 2023, 'Ticker': 'JNJ', 'Total_Volume': 2798287435.0},
#  {'Year': 2023, 'Ticker': 'TSM', 'Total_Volume': 2668485263.0},
#  {'Year': 2022, 'Ticker': 'MRK', 'Total_Volume': 2652581111.0},
#  {'Year': 2018, 'Ticker': 'MS', 'Total_Volume': 2615913900.0},
#  {'Year': 2019, 'Ticker': 'MS', 'Total_Volume': 2610298700.0},
#  {'Year': 2020, 'Ticker': 'MRK', 'Total_Volume': 2595618998.0},
#  {'Year': 2020, 'Ticker': 'QCOM', 'Total_Volume': 2478365374.0},
#  {'Year': 2022, 'Ticker': 'INFY', 'Total_Volume': 2475180940.0},
#  {'Year': 2020, 'Ticker': 'V', 'Total_Volume': 2462070000.0},
#  {'Year': 2019, 'Ticker': 'MRK', 'Total_Volume': 2460517853.0},
#  {'Year': 2021, 'Ticker': 'MS', 'Total_Volume': 2455031800.0},
#  {'Year': 2019, 'Ticker': 'CVS', 'Total_Volume': 2404562844.0},
#  {'Year': 2020, 'Ticker': 'TSM', 'Total_Volume': 2399193194.0},
#  {'Year': 2021, 'Ticker': 'TSM', 'Total_Volume': 2397735264.0},
#  {'Year': 2022, 'Ticker': 'QCOM', 'Total_Volume': 2374247058.0},
#  {'Year': 2019, 'Ticker': 'TSLA', 'Total_Volume': 2316503502.0},
#  {'Year': 2021, 'Ticker': 'QCOM', 'Total_Volume': 2307926184.0},
#  {'Year': 2019, 'Ticker': 'GM', 'Total_Volume': 2212758630.0},
#  {'Year': 2022, 'Ticker': 'MS', 'Total_Volume': 2212605900.0},
#  {'Year': 2020, 'Ticker': 'CVS', 'Total_Volume': 2203753947.0},
#  {'Year': 2021, 'Ticker': 'V', 'Total_Volume': 2201286600.0},
#  {'Year': 2023, 'Ticker': 'CVS', 'Total_Volume': 2157462236.0},
#  {'Year': 2018, 'Ticker': 'TSLA', 'Total_Volume': 2156836605.0},
#  {'Year': 2018, 'Ticker': 'V', 'Total_Volume': 2147651800.0},
#  {'Year': 2021, 'Ticker': 'AZN', 'Total_Volume': 2139881867.0},
#  {'Year': 2024, 'Ticker': 'F', 'Total_Volume': 2134636988.0},
#  {'Year': 2018, 'Ticker': 'CVS', 'Total_Volume': 2118853144.0},
#  {'Year': 2023, 'Ticker': 'INFY', 'Total_Volume': 2069649940.0},
#  {'Year': 2020, 'Ticker': 'JNJ', 'Total_Volume': 2033419386.0},
#  {'Year': 2018, 'Ticker': 'TSM', 'Total_Volume': 2018860371.0},
#  {'Year': 2022, 'Ticker': 'CRM', 'Total_Volume': 1925142741.0},
#  {'Year': 2023, 'Ticker': 'MS', 'Total_Volume': 1924316700.0},
#  {'Year': 2019, 'Ticker': 'TSM', 'Total_Volume': 1919251627.0},
#  {'Year': 2023, 'Ticker': 'MRK', 'Total_Volume': 1917020667.0},
#  {'Year': 2018, 'Ticker': 'JNJ', 'Total_Volume': 1913754278.0},
#  {'Year': 2019, 'Ticker': 'V', 'Total_Volume': 1904911500.0},
#  {'Year': 2020, 'Ticker': 'CRM', 'Total_Volume': 1899301521.0},
#  {'Year': 2024, 'Ticker': 'NVDA', 'Total_Volume': 1898062217.0},
#  {'Year': 2023, 'Ticker': 'QCOM', 'Total_Volume': 1885303372.0},
#  {'Year': 2022, 'Ticker': 'V', 'Total_Volume': 1884574000.0},
#  {'Year': 2022, 'Ticker': 'JNJ', 'Total_Volume': 1820903214.0},
#  {'Year': 2018, 'Ticker': 'INFY', 'Total_Volume': 1796432634.0},
#  {'Year': 2021, 'Ticker': 'JNJ', 'Total_Volume': 1791705525.0},
#  {'Year': 2019, 'Ticker': 'JNJ', 'Total_Volume': 1787992433.0},
#  {'Year': 2019, 'Ticker': 'LLY', 'Total_Volume': 1780848139.0},
#  {'Year': 2021, 'Ticker': 'INFY', 'Total_Volume': 1776731402.0},
#  {'Year': 2024, 'Ticker': 'INTC', 'Total_Volume': 1689284470.0},
#  {'Year': 2022, 'Ticker': 'AZN', 'Total_Volume': 1648388896.0},
#  {'Year': 2024, 'Ticker': 'PFE', 'Total_Volume': 1606353044.0},
#  {'Year': 2022, 'Ticker': 'MRNA', 'Total_Volume': 1555229369.0},
#  {'Year': 2021, 'Ticker': 'CVS', 'Total_Volume': 1552458436.0},
#  {'Year': 2021, 'Ticker': 'CRM', 'Total_Volume': 1549273855.0},
#  {'Year': 2020, 'Ticker': 'AZN', 'Total_Volume': 1519266368.0},
#  {'Year': 2023, 'Ticker': 'CRM', 'Total_Volume': 1516201162.0},
#  {'Year': 2023, 'Ticker': 'V', 'Total_Volume': 1492772700.0},
#  {'Year': 2018, 'Ticker': 'TXN', 'Total_Volume': 1489688952.0},
#  {'Year': 2022, 'Ticker': 'TXN', 'Total_Volume': 1477339147.0},
#  {'Year': 2018, 'Ticker': 'CRM', 'Total_Volume': 1452260009.0},
#  {'Year': 2022, 'Ticker': 'CVS', 'Total_Volume': 1436136538.0},
#  {'Year': 2019, 'Ticker': 'CRM', 'Total_Volume': 1426053880.0},
#  {'Year': 2023, 'Ticker': 'ZI', 'Total_Volume': 1414478363.0},
#  {'Year': 2020, 'Ticker': 'IBM', 'Total_Volume': 1402433673.0},
#  {'Year': 2018, 'Ticker': 'IBM', 'Total_Volume': 1360428693.0},
#  {'Year': 2021, 'Ticker': 'IBM', 'Total_Volume': 1350035200.0},
#  {'Year': 2020, 'Ticker': 'AXP', 'Total_Volume': 1326744900.0},
#  {'Year': 2020, 'Ticker': 'TXN', 'Total_Volume': 1303744064.0},
#  {'Year': 2023, 'Ticker': 'AZN', 'Total_Volume': 1260282521.0},
#  {'Year': 2022, 'Ticker': 'IBM', 'Total_Volume': 1256704835.0},
#  {'Year': 2019, 'Ticker': 'TXN', 'Total_Volume': 1244333223.0},
#  {'Year': 2020, 'Ticker': 'MA', 'Total_Volume': 1188821000.0},
#  {'Year': 2023, 'Ticker': 'TXN', 'Total_Volume': 1188435964.0},
#  {'Year': 2020, 'Ticker': 'FI', 'Total_Volume': 1165552516.0},
#  {'Year': 2021, 'Ticker': 'FI', 'Total_Volume': 1107944248.0},
#  {'Year': 2019, 'Ticker': 'UNH', 'Total_Volume': 1099105818.0},
#  {'Year': 2020, 'Ticker': 'BEN', 'Total_Volume': 1092040500.0},
#  {'Year': 2018, 'Ticker': 'LLY', 'Total_Volume': 1081176373.0},
#  {'Year': 2019, 'Ticker': 'FI', 'Total_Volume': 1078808620.0},
#  {'Year': 2021, 'Ticker': 'TXN', 'Total_Volume': 1069034667.0},
#  {'Year': 2022, 'Ticker': 'ZI', 'Total_Volume': 1048427936.0},
#  {'Year': 2018, 'Ticker': 'AVGO', 'Total_Volume': 1046907418.0},
#  {'Year': 2023, 'Ticker': 'IBM', 'Total_Volume': 1036204541.0},
#  {'Year': 2018, 'Ticker': 'AZN', 'Total_Volume': 1035068230.0},
#  {'Year': 2021, 'Ticker': 'MA', 'Total_Volume': 1023851300.0},
#  {'Year': 2020, 'Ticker': 'AFL', 'Total_Volume': 1021886700.0},
#  {'Year': 2020, 'Ticker': 'UNH', 'Total_Volume': 1018156444.0},
#  {'Year': 2019, 'Ticker': 'AZN', 'Total_Volume': 996850751.0},
#  {'Year': 2020, 'Ticker': 'LLY', 'Total_Volume': 995721044.0},
#  {'Year': 2018, 'Ticker': 'MA', 'Total_Volume': 990197700.0},
#  {'Year': 2019, 'Ticker': 'CTSH', 'Total_Volume': 982646070.0},
#  {'Year': 2020, 'Ticker': 'DFS', 'Total_Volume': 973434900.0},
#  {'Year': 2023, 'Ticker': 'MRNA', 'Total_Volume': 972611665.0},
#  {'Year': 2020, 'Ticker': 'COF', 'Total_Volume': 966861800.0},
#  {'Year': 2019, 'Ticker': 'IBM', 'Total_Volume': 948807295.0},
#  {'Year': 2018, 'Ticker': 'AXP', 'Total_Volume': 922888800.0},
#  {'Year': 2020, 'Ticker': 'SONO', 'Total_Volume': 920066884.0},
#  {'Year': 2018, 'Ticker': 'AFL', 'Total_Volume': 919679600.0},
#  {'Year': 2022, 'Ticker': 'FI', 'Total_Volume': 911930982.0},
#  {'Year': 2020, 'Ticker': 'GS', 'Total_Volume': 908188600.0},
#  {'Year': 2022, 'Ticker': 'ADI', 'Total_Volume': 908110631.0},
#  {'Year': 2018, 'Ticker': 'BEN', 'Total_Volume': 908003800.0},
#  {'Year': 2020, 'Ticker': 'CTSH', 'Total_Volume': 900906400.0},
#  {'Year': 2021, 'Ticker': 'AXP', 'Total_Volume': 899343000.0},
#  {'Year': 2021, 'Ticker': 'ADI', 'Total_Volume': 884539263.0},
#  {'Year': 2018, 'Ticker': 'CTSH', 'Total_Volume': 881793406.0},
#  {'Year': 2022, 'Ticker': 'AXP', 'Total_Volume': 876067800.0},
#  {'Year': 2023, 'Ticker': 'CTSH', 'Total_Volume': 874971115.0},
#  {'Year': 2018, 'Ticker': 'PGR', 'Total_Volume': 871466500.0},
#  {'Year': 2019, 'Ticker': 'MA', 'Total_Volume': 861724200.0},
#  {'Year': 2022, 'Ticker': 'MA', 'Total_Volume': 856334900.0},
#  {'Year': 2022, 'Ticker': 'CTSH', 'Total_Volume': 853906677.0},
#  {'Year': 2018, 'Ticker': 'GS', 'Total_Volume': 849165900.0},
#  {'Year': 2021, 'Ticker': 'LLY', 'Total_Volume': 846562606.0},
#  {'Year': 2023, 'Ticker': 'BEN', 'Total_Volume': 824806200.0},
#  {'Year': 2018, 'Ticker': 'UNH', 'Total_Volume': 822395779.0},
#  {'Year': 2019, 'Ticker': 'AXP', 'Total_Volume': 822191300.0},
#  {'Year': 2023, 'Ticker': 'UNH', 'Total_Volume': 817756939.0},
#  {'Year': 2021, 'Ticker': 'AFL', 'Total_Volume': 815850000.0},
#  {'Year': 2023, 'Ticker': 'AXP', 'Total_Volume': 790056300.0},
#  {'Year': 2019, 'Ticker': 'AFL', 'Total_Volume': 789417700.0},
#  {'Year': 2022, 'Ticker': 'BEN', 'Total_Volume': 787349200.0},
#  {'Year': 2021, 'Ticker': 'ZI', 'Total_Volume': 783847367.0},
#  {'Year': 2023, 'Ticker': 'ADI', 'Total_Volume': 782994543.0},
#  {'Year': 2019, 'Ticker': 'PGR', 'Total_Volume': 782884400.0},
#  {'Year': 2021, 'Ticker': 'CTSH', 'Total_Volume': 781418267.0},
#  {'Year': 2022, 'Ticker': 'UNH', 'Total_Volume': 776678097.0},
#  {'Year': 2021, 'Ticker': 'COF', 'Total_Volume': 767907900.0},
#  {'Year': 2023, 'Ticker': 'LLY', 'Total_Volume': 765839250.0},
#  {'Year': 2020, 'Ticker': 'PGR', 'Total_Volume': 763269200.0},
#  {'Year': 2019, 'Ticker': 'BEN', 'Total_Volume': 751476800.0},
#  {'Year': 2021, 'Ticker': 'UNH', 'Total_Volume': 744759907.0},
#  {'Year': 2021, 'Ticker': 'BEN', 'Total_Volume': 744194800.0},
#  {'Year': 2020, 'Ticker': 'ADI', 'Total_Volume': 741828450.0},
#  {'Year': 2023, 'Ticker': 'FI', 'Total_Volume': 729420050.0},
#  {'Year': 2020, 'Ticker': 'PRU', 'Total_Volume': 728756800.0},
#  {'Year': 2022, 'Ticker': 'LLY', 'Total_Volume': 726382287.0},
#  {'Year': 2018, 'Ticker': 'ADI', 'Total_Volume': 720366477.0},
#  {'Year': 2023, 'Ticker': 'COF', 'Total_Volume': 716334700.0},
#  {'Year': 2022, 'Ticker': 'COF', 'Total_Volume': 703929000.0},
#  {'Year': 2020, 'Ticker': 'HIG', 'Total_Volume': 703022500.0},
#  {'Year': 2023, 'Ticker': 'CPRT', 'Total_Volume': 701506678.0},
#  {'Year': 2022, 'Ticker': 'AFL', 'Total_Volume': 700804100.0},
#  {'Year': 2021, 'Ticker': 'PGR', 'Total_Volume': 693853000.0},
#  {'Year': 2021, 'Ticker': 'GS', 'Total_Volume': 689796200.0},
#  {'Year': 2024, 'Ticker': 'GM', 'Total_Volume': 684137621.0},
#  {'Year': 2022, 'Ticker': 'PGR', 'Total_Volume': 677551900.0},
#  {'Year': 2021, 'Ticker': 'SONO', 'Total_Volume': 674500237.0},
#  {'Year': 2023, 'Ticker': 'AVGO', 'Total_Volume': 664374146.0},
#  {'Year': 2022, 'Ticker': 'SONO', 'Total_Volume': 664029678.0},
#  {'Year': 2022, 'Ticker': 'GS', 'Total_Volume': 659356700.0},
#  {'Year': 2023, 'Ticker': 'MA', 'Total_Volume': 658907400.0},
#  {'Year': 2019, 'Ticker': 'LKQ', 'Total_Volume': 657987071.0},
#  {'Year': 2019, 'Ticker': 'AVGO', 'Total_Volume': 653045979.0},
#  {'Year': 2023, 'Ticker': 'PGR', 'Total_Volume': 651047600.0},
#  {'Year': 2023, 'Ticker': 'MBLY', 'Total_Volume': 650903298.0},
#  {'Year': 2019, 'Ticker': 'GS', 'Total_Volume': 649800700.0},
#  {'Year': 2018, 'Ticker': 'COF', 'Total_Volume': 636238400.0},
#  {'Year': 2020, 'Ticker': 'LKQ', 'Total_Volume': 635443532.0},
#  {'Year': 2019, 'Ticker': 'ADI', 'Total_Volume': 629458615.0},
#  {'Year': 2018, 'Ticker': 'LKQ', 'Total_Volume': 619312412.0},
#  {'Year': 2020, 'Ticker': 'AVGO', 'Total_Volume': 617693145.0},
#  {'Year': 2018, 'Ticker': 'HIG', 'Total_Volume': 617514200.0},
#  {'Year': 2018, 'Ticker': 'CI', 'Total_Volume': 607801207.0},
#  {'Year': 2023, 'Ticker': 'AFL', 'Total_Volume': 603480100.0},
#  {'Year': 2022, 'Ticker': 'AVGO', 'Total_Volume': 597302593.0},
#  {'Year': 2019, 'Ticker': 'CI', 'Total_Volume': 593811435.0},
#  {'Year': 2023, 'Ticker': 'NVO', 'Total_Volume': 589791633.0},
#  {'Year': 2020, 'Ticker': 'ACN', 'Total_Volume': 586446910.0},
#  {'Year': 2023, 'Ticker': 'GS', 'Total_Volume': 585726800.0},
#  {'Year': 2022, 'Ticker': 'ACN', 'Total_Volume': 585366671.0},
#  {'Year': 2023, 'Ticker': 'ARM', 'Total_Volume': 582910498.0},
#  {'Year': 2023, 'Ticker': 'DFS', 'Total_Volume': 582065800.0},
#  {'Year': 2021, 'Ticker': 'HIG', 'Total_Volume': 573813600.0},
#  {'Year': 2019, 'Ticker': 'COF', 'Total_Volume': 571402800.0},
#  {'Year': 2018, 'Ticker': 'ACN', 'Total_Volume': 566717428.0},
#  {'Year': 2018, 'Ticker': 'PRU', 'Total_Volume': 539216600.0},
#  {'Year': 2024, 'Ticker': 'TSM', 'Total_Volume': 539212777.0},
#  {'Year': 2019, 'Ticker': 'NOW', 'Total_Volume': 536892552.0},
#  {'Year': 2018, 'Ticker': 'DFS', 'Total_Volume': 536162800.0},
#  {'Year': 2020, 'Ticker': 'CI', 'Total_Volume': 534285771.0},
#  {'Year': 2018, 'Ticker': 'ALL', 'Total_Volume': 529823400.0},
#  {'Year': 2022, 'Ticker': 'ISRG', 'Total_Volume': 527689599.0},
#  {'Year': 2019, 'Ticker': 'PRU', 'Total_Volume': 525287800.0},
#  {'Year': 2020, 'Ticker': 'ALL', 'Total_Volume': 518871000.0},
#  {'Year': 2023, 'Ticker': 'KMX', 'Total_Volume': 517650152.0},
#  {'Year': 2023, 'Ticker': 'ACN', 'Total_Volume': 515123665.0},
#  {'Year': 2022, 'Ticker': 'APTV', 'Total_Volume': 511997389.0},
#  {'Year': 2018, 'Ticker': 'CPRT', 'Total_Volume': 511053510.0},
#  {'Year': 2021, 'Ticker': 'DFS', 'Total_Volume': 510461700.0},
#  {'Year': 2023, 'Ticker': 'APTV', 'Total_Volume': 508348412.0},
#  {'Year': 2020, 'Ticker': 'APTV', 'Total_Volume': 508146904.0},
#  {'Year': 2021, 'Ticker': 'PRU', 'Total_Volume': 501819600.0},
#  {'Year': 2021, 'Ticker': 'ACN', 'Total_Volume': 501411427.0},
#  {'Year': 2019, 'Ticker': 'HIG', 'Total_Volume': 497951100.0},
#  {'Year': 2022, 'Ticker': 'KMX', 'Total_Volume': 497642399.0},
#  {'Year': 2018, 'Ticker': 'NOW', 'Total_Volume': 496712539.0},
#  {'Year': 2021, 'Ticker': 'VRTX', 'Total_Volume': 495026171.0},
#  {'Year': 2022, 'Ticker': 'ALL', 'Total_Volume': 492862100.0},
#  {'Year': 2022, 'Ticker': 'HIG', 'Total_Volume': 479613000.0},
#  {'Year': 2023, 'Ticker': 'PRU', 'Total_Volume': 478164700.0},
#  {'Year': 2024, 'Ticker': 'CVS', 'Total_Volume': 477804389.0},
#  {'Year': 2022, 'Ticker': 'PRU', 'Total_Volume': 475822400.0},
#  {'Year': 2021, 'Ticker': 'AVGO', 'Total_Volume': 474744375.0},
#  {'Year': 2021, 'Ticker': 'CI', 'Total_Volume': 474442100.0},
#  {'Year': 2023, 'Ticker': 'SONO', 'Total_Volume': 474214794.0},
#  {'Year': 2019, 'Ticker': 'ACN', 'Total_Volume': 470957151.0},
#  {'Year': 2018, 'Ticker': 'APTV', 'Total_Volume': 468642740.0},
#  {'Year': 2019, 'Ticker': 'DFS', 'Total_Volume': 468249500.0},
#  {'Year': 2021, 'Ticker': 'ALL', 'Total_Volume': 466999300.0},
#  {'Year': 2020, 'Ticker': 'NOW', 'Total_Volume': 465264044.0},
#  {'Year': 2018, 'Ticker': 'KMX', 'Total_Volume': 463116782.0},
#  {'Year': 2020, 'Ticker': 'VRTX', 'Total_Volume': 462101694.0},
#  {'Year': 2020, 'Ticker': 'BDX', 'Total_Volume': 461568786.0},
#  {'Year': 2022, 'Ticker': 'DFS', 'Total_Volume': 455906200.0},
#  {'Year': 2022, 'Ticker': 'INTU', 'Total_Volume': 453663880.0},
#  {'Year': 2022, 'Ticker': 'CI', 'Total_Volume': 450218319.0},
#  {'Year': 2022, 'Ticker': 'TROW', 'Total_Volume': 447761600.0},
#  {'Year': 2023, 'Ticker': 'ALL', 'Total_Volume': 445633400.0},
#  {'Year': 2019, 'Ticker': 'ALL', 'Total_Volume': 443730500.0},
#  {'Year': 2023, 'Ticker': 'ISRG', 'Total_Volume': 435542375.0},
#  {'Year': 2022, 'Ticker': 'NOW', 'Total_Volume': 433033079.0},
#  {'Year': 2020, 'Ticker': 'CPRT', 'Total_Volume': 432237914.0},
#  {'Year': 2023, 'Ticker': 'HIG', 'Total_Volume': 431310000.0},
#  {'Year': 2021, 'Ticker': 'LKQ', 'Total_Volume': 429693265.0},
#  {'Year': 2018, 'Ticker': 'FI', 'Total_Volume': 426820679.0},
#  {'Year': 2023, 'Ticker': 'CI', 'Total_Volume': 426126576.0},
#  {'Year': 2020, 'Ticker': 'KMX', 'Total_Volume': 418327154.0},
#  {'Year': 2019, 'Ticker': 'ELV', 'Total_Volume': 414467952.0},
#  {'Year': 2022, 'Ticker': 'LKQ', 'Total_Volume': 410111298.0},
#  {'Year': 2020, 'Ticker': 'ZI', 'Total_Volume': 401367080.0},
#  {'Year': 2019, 'Ticker': 'KMX', 'Total_Volume': 399348221.0},
#  {'Year': 2019, 'Ticker': 'MRNA', 'Total_Volume': 395854196.0},
#  {'Year': 2020, 'Ticker': 'ELV', 'Total_Volume': 394692445.0},
#  {'Year': 2022, 'Ticker': 'VRTX', 'Total_Volume': 394479978.0},
#  {'Year': 2018, 'Ticker': 'NVO', 'Total_Volume': 385395936.0},
#  {'Year': 2018, 'Ticker': 'INTU', 'Total_Volume': 384544014.0},
#  {'Year': 2018, 'Ticker': 'VRTX', 'Total_Volume': 379541879.0},
#  {'Year': 2021, 'Ticker': 'APTV', 'Total_Volume': 376197092.0},
#  {'Year': 2023, 'Ticker': 'TROW', 'Total_Volume': 375438600.0},
#  {'Year': 2022, 'Ticker': 'NVO', 'Total_Volume': 375438568.0},
#  {'Year': 2018, 'Ticker': 'TROW', 'Total_Volume': 370178500.0},
#  {'Year': 2019, 'Ticker': 'APTV', 'Total_Volume': 366404227.0},
#  {'Year': 2020, 'Ticker': 'NVO', 'Total_Volume': 364573011.0},
#  {'Year': 2023, 'Ticker': 'INTU', 'Total_Volume': 364379750.0},
#  {'Year': 2023, 'Ticker': 'LKQ', 'Total_Volume': 363761671.0},
#  {'Year': 2019, 'Ticker': 'CPRT', 'Total_Volume': 361230870.0},
#  {'Year': 2019, 'Ticker': 'NVO', 'Total_Volume': 358472851.0},
#  {'Year': 2023, 'Ticker': 'SGEN', 'Total_Volume': 353352726.0},
#  {'Year': 2018, 'Ticker': 'ELV', 'Total_Volume': 352750231.0},
#  {'Year': 2019, 'Ticker': 'INTU', 'Total_Volume': 351458243.0},
#  {'Year': 2019, 'Ticker': 'SONO', 'Total_Volume': 349882189.0},
#  {'Year': 2021, 'Ticker': 'MGA', 'Total_Volume': 348016725.0},
#  {'Year': 2020, 'Ticker': 'INTU', 'Total_Volume': 346035435.0},
#  {'Year': 2021, 'Ticker': 'BDX', 'Total_Volume': 343622099.0},
#  {'Year': 2022, 'Ticker': 'CPRT', 'Total_Volume': 334368470.0},
#  {'Year': 2018, 'Ticker': 'MGA', 'Total_Volume': 332169643.0},
#  {'Year': 2020, 'Ticker': 'TROW', 'Total_Volume': 331230800.0},
#  {'Year': 2021, 'Ticker': 'NOW', 'Total_Volume': 330904797.0},
#  {'Year': 2019, 'Ticker': 'SONY', 'Total_Volume': 329861875.0},
#  {'Year': 2021, 'Ticker': 'INTU', 'Total_Volume': 329704545.0},
#  {'Year': 2023, 'Ticker': 'NOW', 'Total_Volume': 326030723.0},
#  {'Year': 2019, 'Ticker': 'VRTX', 'Total_Volume': 324857992.0},
#  {'Year': 2024, 'Ticker': 'MS', 'Total_Volume': 321541900.0},
#  {'Year': 2020, 'Ticker': 'ALC', 'Total_Volume': 314717951.0},
#  {'Year': 2022, 'Ticker': 'MGA', 'Total_Volume': 314160425.0},
#  {'Year': 2023, 'Ticker': 'BDX', 'Total_Volume': 313560240.0},
#  {'Year': 2020, 'Ticker': 'SONY', 'Total_Volume': 311023291.0},
#  {'Year': 2022, 'Ticker': 'BDX', 'Total_Volume': 309778165.0},
#  {'Year': 2023, 'Ticker': 'VRTX', 'Total_Volume': 306471408.0},
#  {'Year': 2022, 'Ticker': 'SAP', 'Total_Volume': 303835886.0},
#  {'Year': 2022, 'Ticker': 'HMC', 'Total_Volume': 301392251.0},
#  {'Year': 2023, 'Ticker': 'HUM', 'Total_Volume': 299903124.0},
#  {'Year': 2019, 'Ticker': 'HUM', 'Total_Volume': 297189604.0},
#  {'Year': 2018, 'Ticker': 'BDX', 'Total_Volume': 294994213.0},
#  {'Year': 2019, 'Ticker': 'BDX', 'Total_Volume': 294359126.0},
#  {'Year': 2023, 'Ticker': 'ELV', 'Total_Volume': 290802948.0},
#  {'Year': 2024, 'Ticker': 'MRK', 'Total_Volume': 288573866.0},
#  {'Year': 2021, 'Ticker': 'KMX', 'Total_Volume': 288149404.0},
#  {'Year': 2021, 'Ticker': 'ELV', 'Total_Volume': 287007020.0},
#  {'Year': 2023, 'Ticker': 'MGA', 'Total_Volume': 283876231.0},
#  {'Year': 2018, 'Ticker': 'SONY', 'Total_Volume': 283631264.0},
#  {'Year': 2019, 'Ticker': 'TROW', 'Total_Volume': 282414400.0},
#  {'Year': 2022, 'Ticker': 'SGEN', 'Total_Volume': 282307238.0},
#  {'Year': 2020, 'Ticker': 'REGN', 'Total_Volume': 279167097.0},
#  {'Year': 2024, 'Ticker': 'AZN', 'Total_Volume': 277417163.0},
#  {'Year': 2020, 'Ticker': 'SGEN', 'Total_Volume': 277070226.0},
#  {'Year': 2024, 'Ticker': 'JNJ', 'Total_Volume': 274334705.0},
#  {'Year': 2022, 'Ticker': 'ELV', 'Total_Volume': 272689635.0},
#  {'Year': 2020, 'Ticker': 'MGA', 'Total_Volume': 267198724.0},
#  {'Year': 2023, 'Ticker': 'HMC', 'Total_Volume': 265822317.0},
#  {'Year': 2021, 'Ticker': 'TROW', 'Total_Volume': 263668900.0},
#  {'Year': 2020, 'Ticker': 'COOP', 'Total_Volume': 257945600.0},
#  {'Year': 2020, 'Ticker': 'HUM', 'Total_Volume': 256225585.0},
#  {'Year': 2022, 'Ticker': 'HUM', 'Total_Volume': 256061307.0},
#  {'Year': 2019, 'Ticker': 'MGA', 'Total_Volume': 251325588.0},
#  {'Year': 2021, 'Ticker': 'NVO', 'Total_Volume': 249996496.0},
#  {'Year': 2018, 'Ticker': 'SGEN', 'Total_Volume': 248728656.0},
#  {'Year': 2021, 'Ticker': 'CPRT', 'Total_Volume': 248615282.0},
#  {'Year': 2019, 'Ticker': 'ALC', 'Total_Volume': 246454801.0},
#  {'Year': 2023, 'Ticker': 'RMD', 'Total_Volume': 245775050.0},
#  {'Year': 2019, 'Ticker': 'SGEN', 'Total_Volume': 244694227.0},
#  {'Year': 2018, 'Ticker': 'SAP', 'Total_Volume': 242631175.0},
#  {'Year': 2020, 'Ticker': 'SAP', 'Total_Volume': 240269864.0},
#  {'Year': 2023, 'Ticker': 'ALV', 'Total_Volume': 239172820.0},
#  {'Year': 2021, 'Ticker': 'AN', 'Total_Volume': 237972327.0},
#  {'Year': 2021, 'Ticker': 'SGEN', 'Total_Volume': 226059062.0},
#  {'Year': 2020, 'Ticker': 'BLK', 'Total_Volume': 224648400.0},
#  {'Year': 2022, 'Ticker': 'ALC', 'Total_Volume': 222987909.0},
#  {'Year': 2020, 'Ticker': 'AN', 'Total_Volume': 221615313.0},
#  {'Year': 2024, 'Ticker': 'MBLY', 'Total_Volume': 219688414.0},
#  {'Year': 2023, 'Ticker': 'ALC', 'Total_Volume': 219682789.0},
#  {'Year': 2022, 'Ticker': 'AN', 'Total_Volume': 219366452.0},
#  {'Year': 2021, 'Ticker': 'HUM', 'Total_Volume': 217086489.0},
#  {'Year': 2018, 'Ticker': 'AN', 'Total_Volume': 216788320.0},
#  {'Year': 2022, 'Ticker': 'BLK', 'Total_Volume': 213545200.0},
#  {'Year': 2021, 'Ticker': 'REGN', 'Total_Volume': 211437902.0},
#  {'Year': 2021, 'Ticker': 'HMC', 'Total_Volume': 209823719.0},
#  {'Year': 2020, 'Ticker': 'PFSI', 'Total_Volume': 208978900.0},
#  {'Year': 2022, 'Ticker': 'SONY', 'Total_Volume': 207257892.0},
#  {'Year': 2023, 'Ticker': 'SAP', 'Total_Volume': 207201374.0},
#  {'Year': 2018, 'Ticker': 'REGN', 'Total_Volume': 206306405.0},
#  {'Year': 2021, 'Ticker': 'ALC', 'Total_Volume': 203799903.0},
#  {'Year': 2024, 'Ticker': 'V', 'Total_Volume': 202842900.0},
#  {'Year': 2018, 'Ticker': 'SONO', 'Total_Volume': 202434235.0},
#  {'Year': 2018, 'Ticker': 'ISRG', 'Total_Volume': 201647481.0},
#  {'Year': 2018, 'Ticker': 'HUM', 'Total_Volume': 201228014.0},
#  {'Year': 2021, 'Ticker': 'ISRG', 'Total_Volume': 200236188.0},
#  {'Year': 2021, 'Ticker': 'COOP', 'Total_Volume': 199618500.0},
#  {'Year': 2020, 'Ticker': 'HMC', 'Total_Volume': 198569280.0},
#  {'Year': 2022, 'Ticker': 'LDI', 'Total_Volume': 198008700.0},
#  {'Year': 2019, 'Ticker': 'REGN', 'Total_Volume': 194455377.0},
#  {'Year': 2022, 'Ticker': 'COOP', 'Total_Volume': 190745900.0},
#  {'Year': 2019, 'Ticker': 'COOP', 'Total_Volume': 190457000.0},
#  {'Year': 2019, 'Ticker': 'SAP', 'Total_Volume': 187494175.0},
#  {'Year': 2024, 'Ticker': 'NVO', 'Total_Volume': 185596700.0},
#  {'Year': 2018, 'Ticker': 'RMD', 'Total_Volume': 184078713.0},
#  {'Year': 2021, 'Ticker': 'SONY', 'Total_Volume': 183754108.0},
#  {'Year': 2020, 'Ticker': 'ISRG', 'Total_Volume': 182668464.0},
#  {'Year': 2019, 'Ticker': 'AN', 'Total_Volume': 182633796.0},
#  {'Year': 2021, 'Ticker': 'PFSI', 'Total_Volume': 181616400.0},
#  {'Year': 2018, 'Ticker': 'LPL', 'Total_Volume': 181055851.0},
#  {'Year': 2021, 'Ticker': 'SAP', 'Total_Volume': 179847648.0},
#  {'Year': 2023, 'Ticker': 'SONY', 'Total_Volume': 179017762.0},
#  {'Year': 2019, 'Ticker': 'RMD', 'Total_Volume': 177291762.0},
#  {'Year': 2022, 'Ticker': 'ALV', 'Total_Volume': 176695973.0},
#  {'Year': 2024, 'Ticker': 'MRNA', 'Total_Volume': 176462663.0},
#  {'Year': 2022, 'Ticker': 'REGN', 'Total_Volume': 175667313.0},
#  {'Year': 2018, 'Ticker': 'HMC', 'Total_Volume': 174793618.0},
#  {'Year': 2021, 'Ticker': 'LPL', 'Total_Volume': 174237131.0},
#  {'Year': 2018, 'Ticker': 'BLK', 'Total_Volume': 172667600.0},
#  {'Year': 2019, 'Ticker': 'ISRG', 'Total_Volume': 171136660.0},
#  {'Year': 2018, 'Ticker': 'ALV', 'Total_Volume': 162291618.0},
#  {'Year': 2020, 'Ticker': 'RMD', 'Total_Volume': 161590018.0},
#  {'Year': 2023, 'Ticker': 'BLK', 'Total_Volume': 161124000.0},
#  {'Year': 2024, 'Ticker': 'CPRT', 'Total_Volume': 156665006.0},
#  {'Year': 2023, 'Ticker': 'AN', 'Total_Volume': 156525300.0},
#  {'Year': 2019, 'Ticker': 'HMC', 'Total_Volume': 155426665.0},
#  {'Year': 2023, 'Ticker': 'COOP', 'Total_Volume': 149194600.0},
#  {'Year': 2024, 'Ticker': 'UNH', 'Total_Volume': 147269257.0},
#  {'Year': 2021, 'Ticker': 'LDI', 'Total_Volume': 145805300.0},
#  {'Year': 2020, 'Ticker': 'WST', 'Total_Volume': 145524372.0},
#  {'Year': 2021, 'Ticker': 'RMD', 'Total_Volume': 144982269.0},
#  {'Year': 2019, 'Ticker': 'ALV', 'Total_Volume': 144574262.0},
#  {'Year': 2020, 'Ticker': 'ALV', 'Total_Volume': 142452791.0},
#  {'Year': 2021, 'Ticker': 'BLK', 'Total_Volume': 142338000.0},
#  {'Year': 2023, 'Ticker': 'REGN', 'Total_Volume': 142036377.0},
#  {'Year': 2022, 'Ticker': 'RMD', 'Total_Volume': 139131736.0},
#  {'Year': 2019, 'Ticker': 'BLK', 'Total_Volume': 138221900.0},
#  {'Year': 2022, 'Ticker': 'PFSI', 'Total_Volume': 136023100.0},
#  {'Year': 2024, 'Ticker': 'BEN', 'Total_Volume': 133390100.0},
#  {'Year': 2024, 'Ticker': 'LLY', 'Total_Volume': 129097994.0},
#  {'Year': 2024, 'Ticker': 'AXP', 'Total_Volume': 128710800.0},
#  {'Year': 2022, 'Ticker': 'WST', 'Total_Volume': 127880302.0},
#  {'Year': 2021, 'Ticker': 'ALV', 'Total_Volume': 127772283.0},
#  {'Year': 2022, 'Ticker': 'LPL', 'Total_Volume': 119463426.0},
#  {'Year': 2024, 'Ticker': 'APTV', 'Total_Volume': 119014197.0},
#  {'Year': 2022, 'Ticker': 'MBLY', 'Total_Volume': 114722894.0},
#  {'Year': 2024, 'Ticker': 'DFS', 'Total_Volume': 110811600.0},
#  {'Year': 2024, 'Ticker': 'COF', 'Total_Volume': 110119100.0},
#  {'Year': 2023, 'Ticker': 'WST', 'Total_Volume': 109603214.0},
#  {'Year': 2018, 'Ticker': 'PAG', 'Total_Volume': 106815905.0},
#  {'Year': 2023, 'Ticker': 'LDI', 'Total_Volume': 101145200.0},
#  {'Year': 2022, 'Ticker': 'PAG', 'Total_Volume': 100993602.0},
#  {'Year': 2024, 'Ticker': 'AVGO', 'Total_Volume': 99514040.0},
#  {'Year': 2021, 'Ticker': 'WST', 'Total_Volume': 99113216.0},
#  {'Year': 2020, 'Ticker': 'LPL', 'Total_Volume': 96874202.0},
#  {'Year': 2019, 'Ticker': 'WST', 'Total_Volume': 95187592.0},
#  {'Year': 2022, 'Ticker': 'LAD', 'Total_Volume': 94869262.0},
#  {'Year': 2019, 'Ticker': 'PAG', 'Total_Volume': 94667891.0},
#  {'Year': 2020, 'Ticker': 'PAG', 'Total_Volume': 94524261.0},
#  {'Year': 2024, 'Ticker': 'MA', 'Total_Volume': 94297000.0},
#  {'Year': 2018, 'Ticker': 'WST', 'Total_Volume': 94076775.0},
#  {'Year': 2018, 'Ticker': 'COOP', 'Total_Volume': 93931032.0},
#  {'Year': 2021, 'Ticker': 'LAD', 'Total_Volume': 92532328.0},
#  {'Year': 2019, 'Ticker': 'LPL', 'Total_Volume': 91034483.0},
#  {'Year': 2024, 'Ticker': 'GS', 'Total_Volume': 87742300.0},
#  {'Year': 2024, 'Ticker': 'HUM', 'Total_Volume': 87364840.0},
#  {'Year': 2020, 'Ticker': 'LAD', 'Total_Volume': 85478498.0},
#  {'Year': 2024, 'Ticker': 'AFL', 'Total_Volume': 83536600.0},
#  {'Year': 2024, 'Ticker': 'PGR', 'Total_Volume': 82452700.0},
#  {'Year': 2018, 'Ticker': 'LAD', 'Total_Volume': 81365326.0},
#  {'Year': 2023, 'Ticker': 'PAG', 'Total_Volume': 81075886.0},
#  {'Year': 2023, 'Ticker': 'PFSI', 'Total_Volume': 80310400.0},
#  {'Year': 2021, 'Ticker': 'PAG', 'Total_Volume': 79177681.0},
#  {'Year': 2019, 'Ticker': 'PFSI', 'Total_Volume': 77963000.0},
#  {'Year': 2021, 'Ticker': 'TM', 'Total_Volume': 70963411.0},
#  {'Year': 2023, 'Ticker': 'TM', 'Total_Volume': 70576830.0},
#  {'Year': 2023, 'Ticker': 'LAD', 'Total_Volume': 68473597.0},
#  {'Year': 2024, 'Ticker': 'KMX', 'Total_Volume': 67355604.0},
#  {'Year': 2024, 'Ticker': 'ISRG', 'Total_Volume': 65866959.0},
#  {'Year': 2022, 'Ticker': 'TM', 'Total_Volume': 65137391.0},
#  {'Year': 2024, 'Ticker': 'HIG', 'Total_Volume': 64864400.0},
#  {'Year': 2024, 'Ticker': 'LKQ', 'Total_Volume': 64583839.0},
#  {'Year': 2024, 'Ticker': 'CI', 'Total_Volume': 63853862.0},
#  {'Year': 2020, 'Ticker': 'WD', 'Total_Volume': 62259200.0},
#  {'Year': 2019, 'Ticker': 'LAD', 'Total_Volume': 60115127.0},
#  {'Year': 2024, 'Ticker': 'ALL', 'Total_Volume': 59951900.0},
#  {'Year': 2024, 'Ticker': 'PRU', 'Total_Volume': 59387500.0},
#  {'Year': 2024, 'Ticker': 'BDX', 'Total_Volume': 58338336.0},
#  {'Year': 2024, 'Ticker': 'VRTX', 'Total_Volume': 56897675.0},
#  {'Year': 2024, 'Ticker': 'TROW', 'Total_Volume': 55101200.0},
#  {'Year': 2018, 'Ticker': 'WD', 'Total_Volume': 54260700.0},
#  {'Year': 2020, 'Ticker': 'TM', 'Total_Volume': 53921670.0},
#  {'Year': 2018, 'Ticker': 'TM', 'Total_Volume': 50687447.0},
#  {'Year': 2018, 'Ticker': 'PFSI', 'Total_Volume': 50420600.0},
#  {'Year': 2023, 'Ticker': 'WD', 'Total_Volume': 50180800.0},
#  {'Year': 2024, 'Ticker': 'MGA', 'Total_Volume': 49668853.0},
#  {'Year': 2023, 'Ticker': 'LPL', 'Total_Volume': 40746336.0},
#  {'Year': 2024, 'Ticker': 'ELV', 'Total_Volume': 40540077.0},
#  {'Year': 2018, 'Ticker': 'MRNA', 'Total_Volume': 40359984.0},
#  {'Year': 2022, 'Ticker': 'WD', 'Total_Volume': 39475400.0},
#  {'Year': 2019, 'Ticker': 'WD', 'Total_Volume': 37565800.0},
#  {'Year': 2021, 'Ticker': 'WD', 'Total_Volume': 36759200.0},
#  {'Year': 2024, 'Ticker': 'HMC', 'Total_Volume': 36646482.0},
#  {'Year': 2019, 'Ticker': 'TM', 'Total_Volume': 35100677.0},
#  {'Year': 2024, 'Ticker': 'RMD', 'Total_Volume': 34353674.0},
#  {'Year': 2024, 'Ticker': 'ALC', 'Total_Volume': 32297455.0},
#  {'Year': 2024, 'Ticker': 'BLK', 'Total_Volume': 22574700.0},
#  {'Year': 2024, 'Ticker': 'WST', 'Total_Volume': 22297859.0},
#  {'Year': 2024, 'Ticker': 'ALV', 'Total_Volume': 21424310.0},
#  {'Year': 2024, 'Ticker': 'REGN', 'Total_Volume': 20367573.0},
#  {'Year': 2024, 'Ticker': 'LDI', 'Total_Volume': 19746200.0},
#  {'Year': 2020, 'Ticker': 'GHI', 'Total_Volume': 19453061.0},
#  {'Year': 2024, 'Ticker': 'COOP', 'Total_Volume': 19317600.0},
#  {'Year': 2024, 'Ticker': 'AN', 'Total_Volume': 15637135.0},
#  {'Year': 2021, 'Ticker': 'GHI', 'Total_Volume': 15183008.0},
#  {'Year': 2024, 'Ticker': 'TM', 'Total_Volume': 12190890.0},
#  {'Year': 2019, 'Ticker': 'GHI', 'Total_Volume': 11297492.0},
#  {'Year': 2022, 'Ticker': 'GHI', 'Total_Volume': 10558602.0},
#  {'Year': 2023, 'Ticker': 'GHI', 'Total_Volume': 9337400.0},
#  {'Year': 2024, 'Ticker': 'PFSI', 'Total_Volume': 8621400.0},
#  {'Year': 2018, 'Ticker': 'GHI', 'Total_Volume': 8055403.0},
#  {'Year': 2024, 'Ticker': 'WD', 'Total_Volume': 7952200.0},
#  {'Year': 2024, 'Ticker': 'PAG', 'Total_Volume': 7535303.0},
#  {'Year': 2024, 'Ticker': 'LAD', 'Total_Volume': 7111861.0},
#  {'Year': 2024, 'Ticker': 'GHI', 'Total_Volume': 1464200.0},
#  {'Year': 2024, 'Ticker': 'SGEN', 'Total_Volume': 86.0}]
